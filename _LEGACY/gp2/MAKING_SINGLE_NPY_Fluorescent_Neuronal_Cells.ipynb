# %% [markdown]
# # USE OF SIMPLE API TO CONVERT SEGMENTATION DATASETS TO NPY

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0,'../..')
from PIL import Image
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import omama as O

# %%
images_name = 'Fluorescent_Neuronal_Cells'
masks_name = 'Fluorescent_Neuronal_Cells_masks'
brain_root = '/hpcstor6/scratch01/r/ryan.zurrin001/Fluorescent_Neuronal_Cells'
brain_out = '/hpcstor6/scratch01/r/ryan.zurrin001/Fluorescent_Neuronal_Cells/all_images/images/'
brain_mask = '/hpcstor6/scratch01/r/ryan.zurrin001/Fluorescent_Neuronal_Cells/all_masks/masks/'

# %%
converter = O.DataToNpyFiles(brain_out, brain_mask, brain_root, images_name, masks_name, '.png')
# Out:
# Images and masks saved to /hpcstor6/scratch01/r/ryan.zurrin001/Fluorescent_Neuronal_Cells

# %%
print(converter)
# Out:
# DataToNpyFiles(image_dir=/hpcstor6/scratch01/r/ryan.zurrin001/Fluorescent_Neuronal_Cells/all_images/images, mask_dir=/hpcstor6/scratch01/r/ryan.zurrin001/Fluorescent_Neuronal_Cells/all_masks/masks, output_dir=/hpcstor6/scratch01/r/ryan.zurrin001/Fluorescent_Neuronal_Cells, image_extension=.png)

# %%
len(converter.image_paths)
# Out:
# 283

# %%
len(converter.mask_paths)
# Out:
# 283

# %%
converter.display_image_and_mask(3)

# %%
images, masks = converter.load_data() # easily  load the imagers and masks now

# %%
converter.reshape_all_images_and_masks()  # shape converter lets you resize fast
# Out:
# 100%|██████████████████████████████████████████████████████████████| 283/283 [00:20<00:00, 13.74it/s]
