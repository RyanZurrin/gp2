# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0,'../..')
from PIL import Image
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
images_name = '102Flower_segmentation_images'
masks_name = '102Flower_segmentation_masks'
img_root = '/hpcstor6/scratch01/r/ryan.zurrin001/Flower_dataset/images/'
mask_root = '/hpcstor6/scratch01/r/ryan.zurrin001/Flower_dataset/masks/'
output_dir = '/hpcstor6/scratch01/r/ryan.zurrin001/Flower_dataset/'

# %%
converter = O.DataToNpyFiles(image_dir=img_root,
                             mask_dir=mask_root,
                             output_dir=output_dir,
                             images_file_name=images_name,
                             masks_file_name=masks_name,
                             image_extension='jpg')
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8189/8189 [00:34<00:00, 237.26it/s]
# /home/ryan.zurrin001/Projects/CS410-Omama/_DATA/gp2/../../omama/utils/data_to_npy_files.py:123: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   images = np.array(images)
# /home/ryan.zurrin001/Projects/CS410-Omama/_DATA/gp2/../../omama/utils/data_to_npy_files.py:124: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   masks = np.array(masks)
# ...

# %%
len(converter.image_paths)
# Out:
# 8189

# %%
len(converter.mask_paths)
# Out:
# 8189

# %%
converter.display_image_and_mask(313)

# %%
images, masks = converter.load_data() # easily  load the imagers and masks now

# %%
images.shape
# Out:
# (8189,)

# %%
masks.shape
# Out:
# (8189,)

# %%
converter.reshape_all_images_and_masks()  # shape converter lets you resize fast
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8189/8189 [09:41<00:00, 14.07it/s]

# %%
converter.fix_dtype()
# Out:
# Temp image directory: /tmp/tmp9wq4z8q8
# Temp mask directory: /tmp/tmpokqqq8h4
# Shape of images in temp image directory: (512, 512, 1)
# Shape of masks in temp mask directory: (512, 512, 1)
# Output directory: /hpcstor6/scratch01/r/ryan.zurrin001/Flower_dataset
# Image name: 102Flower_segmentation_images
# Mask name: 102Flower_segmentation_masks
# Image extension: jpg
# Mask extension: jpg
# temp image directory: /tmp/tmp9wq4z8q8
# temp mask directory: /tmp/tmpokqqq8h4
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8189/8189 [00:07<00:00, 1094.67it/s]
# Images and masks saved to /hpcstor6/scratch01/r/ryan.zurrin001/Flower_dataset

# %%
images3, masks3 = converter.load_data()

# %%
images3.shape
# Out:
# (8189, 512, 512, 1)

# %%
masks3.shape
# Out:
# (8189, 512, 512, 1)
