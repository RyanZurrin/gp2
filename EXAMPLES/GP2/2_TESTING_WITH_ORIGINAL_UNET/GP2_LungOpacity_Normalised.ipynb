# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import time
import sys
# !pip install tensorflow
# import pickle
# import tensorflow as tf
#  UpSampling2D, BatchNormalization
sys.path.insert(0,'../../..')
from gp2 import Runner
# Out:
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
R = Runner(verbose=True)
# Out:
# *** GP2  Unet ***
# Working directory: /tmp/tmpge_vo6u2GP2
# Using default discriminator (CNN)

# %%
# load our larger toy dataset (10k images and masks)
images = np.load('/hpcstor6/scratch01/p/poornendu.pabbati001/Lung_Opacity/Lung_images_final.npy')
masks = np.load('/hpcstor6/scratch01/p/poornendu.pabbati001/Lung_Opacity/Lung_masks_final.npy')

# %%
plt.imshow(images[500])

# %%
plt.imshow(masks[500])

# %%
len(images)
# Out:
# 6012

# %%
weights = {
    'A': 0.5,
    'A_train': 0.1,
    'A_val': 0.3,
    'A_test': 0.6,
    'B': 0.3,
    'B_train': 0.7,
    'B_val': 0.1,
    'B_test': 0.2,
    'Z': 0.2
}

# %%
#
#
R.setup_data(images, masks, dataset_size=6012, weights=weights)
# Out:
# Weights OK!

# %%
RUNS = 5

# %%
for run in range(RUNS):
    print('***')
    print('RUN:', run)
    t0 = time.time()
    R.run_classifier()
    R.run_discriminator()
    R.find_machine_labels()
    R.relabel()
    print('TOOK', time.time()-t0, 'seconds')
# Out:
# ***
# RUN: 0
# Epoch 1/100
# 5/5 [==============================] - 32s 4s/step - loss: 1.3350 - dice_coeff: 0.3712 - val_loss: 1.3876 - val_dice_coeff: 0.3059
# Epoch 2/100
# 5/5 [==============================] - 7s 1s/step - loss: 1.1218 - dice_coeff: 0.4439 - val_loss: 1.3882 - val_dice_coeff: 0.3074
# Epoch 3/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.9890 - dice_coeff: 0.4935 - val_loss: 1.3918 - val_dice_coeff: 0.3089
# Epoch 4/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.9157 - dice_coeff: 0.5201 - val_loss: 1.3964 - val_dice_coeff: 0.3098
# Epoch 5/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.8492 - dice_coeff: 0.5488 - val_loss: 1.4014 - val_dice_coeff: 0.3102
# Epoch 6/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.8105 - dice_coeff: 0.5650 - val_loss: 1.4057 - val_dice_coeff: 0.3107
# Epoch 7/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.7655 - dice_coeff: 0.5851 - val_loss: 1.4096 - val_dice_coeff: 0.3107
# Epoch 8/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.7382 - dice_coeff: 0.5955 - val_loss: 1.4131 - val_dice_coeff: 0.3110
# Epoch 9/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.7330 - dice_coeff: 0.6008 - val_loss: 1.4163 - val_dice_coeff: 0.3109
# Epoch 10/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.6773 - dice_coeff: 0.6259 - val_loss: 1.4192 - val_dice_coeff: 0.3106
# Epoch 11/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.6683 - dice_coeff: 0.6295 - val_loss: 1.4222 - val_dice_coeff: 0.3103
# Epoch 12/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.6683 - dice_coeff: 0.6314 - val_loss: 1.4235 - val_dice_coeff: 0.3103
# Epoch 13/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.6131 - dice_coeff: 0.6551 - val_loss: 1.4233 - val_dice_coeff: 0.3105
# Epoch 14/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.6060 - dice_coeff: 0.6601 - val_loss: 1.4231 - val_dice_coeff: 0.3097
# Epoch 15/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.6229 - dice_coeff: 0.6542 - val_loss: 1.4214 - val_dice_coeff: 0.3085
# Epoch 16/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.5863 - dice_coeff: 0.6688 - val_loss: 1.4177 - val_dice_coeff: 0.3083
# Epoch 17/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.5594 - dice_coeff: 0.6823 - val_loss: 1.4098 - val_dice_coeff: 0.3052
# Epoch 18/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.5647 - dice_coeff: 0.6804 - val_loss: 1.4000 - val_dice_coeff: 0.3039
# Epoch 19/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.5338 - dice_coeff: 0.6949 - val_loss: 1.3925 - val_dice_coeff: 0.3006
# Epoch 20/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.5441 - dice_coeff: 0.6911 - val_loss: 1.3787 - val_dice_coeff: 0.2986
# Epoch 21/100
# 5/5 [==============================] - 7s 2s/step - loss: 0.5309 - dice_coeff: 0.6960 - val_loss: 1.3719 - val_dice_coeff: 0.2976
# Epoch 22/100
# 5/5 [==============================] - 7s 2s/step - loss: 0.5260 - dice_coeff: 0.6992 - val_loss: 1.3161 - val_dice_coeff: 0.3013
# Epoch 23/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.5297 - dice_coeff: 0.6974 - val_loss: 1.3459 - val_dice_coeff: 0.2935
# Epoch 24/100
# 5/5 [==============================] - 7s 2s/step - loss: 0.5000 - dice_coeff: 0.7109 - val_loss: 1.3337 - val_dice_coeff: 0.2928
# Epoch 25/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.5052 - dice_coeff: 0.7088 - val_loss: 1.3282 - val_dice_coeff: 0.2949
# Epoch 26/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.4995 - dice_coeff: 0.7117 - val_loss: 1.3319 - val_dice_coeff: 0.2881
# Epoch 27/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.4993 - dice_coeff: 0.7130 - val_loss: 1.3175 - val_dice_coeff: 0.2923
# Epoch 28/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.4868 - dice_coeff: 0.7174 - val_loss: 1.3079 - val_dice_coeff: 0.2929
# Epoch 29/100
# 5/5 [==============================] - 7s 2s/step - loss: 0.4827 - dice_coeff: 0.7196 - val_loss: 1.2995 - val_dice_coeff: 0.2898
# Epoch 30/100
# 5/5 [==============================] - 7s 2s/step - loss: 0.4644 - dice_coeff: 0.7273 - val_loss: 1.2989 - val_dice_coeff: 0.2897
# Epoch 31/100
# 5/5 [==============================] - 7s 2s/step - loss: 0.4785 - dice_coeff: 0.7227 - val_loss: 1.2957 - val_dice_coeff: 0.2905
# Epoch 32/100
# 5/5 [==============================] - 7s 2s/step - loss: 0.4719 - dice_coeff: 0.7258 - val_loss: 1.2860 - val_dice_coeff: 0.2907
# Model saved to /tmp/tmpge_vo6u2GP2/unet_0.model
# History saved to /tmp/tmpge_vo6u2GP2/history_0.pickle
# Testing the classifier...
# 57/57 [==============================] - 6s 103ms/step - loss: 1.2859 - dice_coeff: 0.2921
# ****** TRAINING DISCRIMINATOR ******
# Model saved to /tmp/tmpge_vo6u2GP2/cnnd_0.model
# History saved to /tmp/tmpge_vo6u2GP2/cnnd_history_0.pickle
# Testing the discriminator...
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Replacing 61 from 184 !
# D_relabeled_ 61
# point ids 61
# Removed: 61 Filled: 61
# TOOK 451.3501431941986 seconds
# ***
# RUN: 1
# Epoch 1/100
# 6/6 [==============================] - 14s 3s/step - loss: 0.4707 - dice_coeff: 0.7268 - val_loss: 1.2910 - val_dice_coeff: 0.2892
# Epoch 2/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4753 - dice_coeff: 0.7244 - val_loss: 1.2920 - val_dice_coeff: 0.2878
# Epoch 3/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4598 - dice_coeff: 0.7313 - val_loss: 1.2760 - val_dice_coeff: 0.2884
# Epoch 4/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4597 - dice_coeff: 0.7309 - val_loss: 1.2910 - val_dice_coeff: 0.2853
# Epoch 5/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4608 - dice_coeff: 0.7312 - val_loss: 1.2748 - val_dice_coeff: 0.2868
# Epoch 6/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4479 - dice_coeff: 0.7364 - val_loss: 1.2728 - val_dice_coeff: 0.2861
# Epoch 7/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4396 - dice_coeff: 0.7408 - val_loss: 1.2750 - val_dice_coeff: 0.2806
# Epoch 8/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4356 - dice_coeff: 0.7413 - val_loss: 1.2756 - val_dice_coeff: 0.2786
# Epoch 9/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4384 - dice_coeff: 0.7412 - val_loss: 1.2602 - val_dice_coeff: 0.2836
# Epoch 10/100
# 6/6 [==============================] - 10s 2s/step - loss: 0.4367 - dice_coeff: 0.7432 - val_loss: 1.2478 - val_dice_coeff: 0.2902
# Model saved to /tmp/tmpge_vo6u2GP2/unet_1.model
# History saved to /tmp/tmpge_vo6u2GP2/history_1.pickle
# Testing the classifier...
# 57/57 [==============================] - 6s 105ms/step - loss: 1.2477 - dice_coeff: 0.2921
# Testing the discriminator...
# 12/12 [==============================] - 1s 41ms/step - loss: 35.8761 - accuracy: 0.6889
# Replacing 21 from 64 !
# D_relabeled_ 21
# point ids 21
# Removed: 21 Filled: 21
# TOOK 242.6913616657257 seconds
# ***
# RUN: 2
# Epoch 1/100
# 6/6 [==============================] - 16s 3s/step - loss: 0.4383 - dice_coeff: 0.7427 - val_loss: 1.2498 - val_dice_coeff: 0.2813
# Epoch 2/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4277 - dice_coeff: 0.7466 - val_loss: 1.2386 - val_dice_coeff: 0.2845
# Epoch 3/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4315 - dice_coeff: 0.7453 - val_loss: 1.1438 - val_dice_coeff: 0.3458
# Epoch 4/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4239 - dice_coeff: 0.7489 - val_loss: 1.2266 - val_dice_coeff: 0.2877
# Epoch 5/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4190 - dice_coeff: 0.7509 - val_loss: 1.2286 - val_dice_coeff: 0.2848
# Epoch 6/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4198 - dice_coeff: 0.7509 - val_loss: 1.1979 - val_dice_coeff: 0.2990
# Epoch 7/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4357 - dice_coeff: 0.7453 - val_loss: 1.0412 - val_dice_coeff: 0.4066
# Model saved to /tmp/tmpge_vo6u2GP2/unet_2.model
# History saved to /tmp/tmpge_vo6u2GP2/history_2.pickle
# Testing the classifier...
# 57/57 [==============================] - 6s 104ms/step - loss: 1.0491 - dice_coeff: 0.4034
# Testing the discriminator...
# 12/12 [==============================] - 1s 38ms/step - loss: 298.4995 - accuracy: 0.5250
# Replacing 1 from 4 !
# D_relabeled_ 1
# point ids 1
# Removed: 1 Filled: 1
# TOOK 182.6818766593933 seconds
# ***
# RUN: 3
# Epoch 1/100
# 6/6 [==============================] - 16s 3s/step - loss: 0.4169 - dice_coeff: 0.7525 - val_loss: 1.0619 - val_dice_coeff: 0.3828
# Epoch 2/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4103 - dice_coeff: 0.7554 - val_loss: 1.0323 - val_dice_coeff: 0.3981
# Epoch 3/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4076 - dice_coeff: 0.7565 - val_loss: 0.9962 - val_dice_coeff: 0.4228
# Epoch 4/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4054 - dice_coeff: 0.7579 - val_loss: 1.0224 - val_dice_coeff: 0.4082
# Epoch 5/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4057 - dice_coeff: 0.7581 - val_loss: 0.9235 - val_dice_coeff: 0.4756
# Epoch 6/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4024 - dice_coeff: 0.7597 - val_loss: 0.9778 - val_dice_coeff: 0.4303
# Epoch 7/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4032 - dice_coeff: 0.7597 - val_loss: 0.9398 - val_dice_coeff: 0.4569
# Epoch 8/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4012 - dice_coeff: 0.7604 - val_loss: 0.8844 - val_dice_coeff: 0.4858
# Epoch 9/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3950 - dice_coeff: 0.7634 - val_loss: 0.8768 - val_dice_coeff: 0.4936
# Epoch 10/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3890 - dice_coeff: 0.7663 - val_loss: 0.8240 - val_dice_coeff: 0.5328
# Epoch 11/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3894 - dice_coeff: 0.7665 - val_loss: 0.7515 - val_dice_coeff: 0.5765
# Epoch 12/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3899 - dice_coeff: 0.7667 - val_loss: 0.7610 - val_dice_coeff: 0.5652
# Model saved to /tmp/tmpge_vo6u2GP2/unet_3.model
# History saved to /tmp/tmpge_vo6u2GP2/history_3.pickle
# Testing the classifier...
# 57/57 [==============================] - 6s 103ms/step - loss: 0.7706 - dice_coeff: 0.5622
# Testing the discriminator...
# 12/12 [==============================] - 1s 41ms/step - loss: 553.1653 - accuracy: 0.4917
# No machine labels found. Skipping step 6.
# Replacing 1 from 4 !
# D_relabeled_ 1
# point ids 1
# Removed: 1 Filled: 1
# TOOK 243.35574173927307 seconds
# ***
# RUN: 4
# Epoch 1/100
# 6/6 [==============================] - 11s 2s/step - loss: 0.3829 - dice_coeff: 0.7694 - val_loss: 0.7455 - val_dice_coeff: 0.5839
# Epoch 2/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3947 - dice_coeff: 0.7650 - val_loss: 0.6996 - val_dice_coeff: 0.6416
# Epoch 3/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3746 - dice_coeff: 0.7733 - val_loss: 0.6465 - val_dice_coeff: 0.6602
# Epoch 4/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3703 - dice_coeff: 0.7758 - val_loss: 0.6189 - val_dice_coeff: 0.6696
# Epoch 5/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3721 - dice_coeff: 0.7751 - val_loss: 0.6289 - val_dice_coeff: 0.6637
# Epoch 6/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3689 - dice_coeff: 0.7769 - val_loss: 0.5973 - val_dice_coeff: 0.6738
# Epoch 7/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.3656 - dice_coeff: 0.7783 - val_loss: 0.6157 - val_dice_coeff: 0.6761
# Epoch 8/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3653 - dice_coeff: 0.7787 - val_loss: 0.6260 - val_dice_coeff: 0.6767
# Epoch 9/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3638 - dice_coeff: 0.7794 - val_loss: 0.6128 - val_dice_coeff: 0.6862
# Epoch 10/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3610 - dice_coeff: 0.7808 - val_loss: 0.5706 - val_dice_coeff: 0.6993
# Epoch 11/100
# 6/6 [==============================] - 8s 2s/step - loss: 0.3562 - dice_coeff: 0.7834 - val_loss: 0.5815 - val_dice_coeff: 0.7026
# Epoch 12/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3562 - dice_coeff: 0.7836 - val_loss: 0.5717 - val_dice_coeff: 0.6982
# Epoch 13/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3580 - dice_coeff: 0.7826 - val_loss: 0.5536 - val_dice_coeff: 0.7014
# Epoch 14/100
# 6/6 [==============================] - 8s 2s/step - loss: 0.3531 - dice_coeff: 0.7849 - val_loss: 0.5418 - val_dice_coeff: 0.7120
# Epoch 15/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3492 - dice_coeff: 0.7869 - val_loss: 0.5310 - val_dice_coeff: 0.7139
# Epoch 16/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3515 - dice_coeff: 0.7858 - val_loss: 0.5746 - val_dice_coeff: 0.7077
# Epoch 17/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3900 - dice_coeff: 0.7717 - val_loss: 1.0950 - val_dice_coeff: 0.6398
# Model saved to /tmp/tmpge_vo6u2GP2/unet_4.model
# History saved to /tmp/tmpge_vo6u2GP2/history_4.pickle
# Testing the classifier...
# 57/57 [==============================] - 6s 104ms/step - loss: 1.1050 - dice_coeff: 0.6414
# Testing the discriminator...
# 12/12 [==============================] - 1s 42ms/step - loss: 866.7465 - accuracy: 0.5083
# No machine labels found. Skipping step 6.
# Replacing 1 from 4 !
# D_relabeled_ 1
# point ids 1
# Removed: 1 Filled: 1
# TOOK 305.9666094779968 seconds

# %%
R.classifier_scores
# Out:
# [[1.2858726978302002, 0.2921049892902374],
#  [1.24765145778656, 0.29213693737983704],
#  [1.0491243600845337, 0.4034401476383209],
#  [0.7706333994865417, 0.5622080564498901],
#  [1.1049890518188477, 0.6414260268211365]]

# %%
R.discriminator_scores
# Out:
# [[0.0, 1.0],
#  [35.87605285644531, 0.6888889074325562],
#  [298.49951171875, 0.5249999761581421],
#  [553.1653442382812, 0.49166667461395264],
#  [866.7464599609375, 0.5083333253860474]]

# %%
R.plot()
