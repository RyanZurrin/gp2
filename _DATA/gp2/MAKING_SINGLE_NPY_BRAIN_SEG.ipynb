# %% [markdown]
# # USE OF SIMPLE API TO CONVERT SEGMENTATION DATASETS TO NPY

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0,'../..')
from PIL import Image
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
images_name = 'Brain_MRI_Segmentation'
masks_name = 'Brain_MRI_Segmentation_masks'
brain_root = '/hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation/lgg-mri-segmentation/kaggle_3m/'
brain_out = '/hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation/lgg-mri-segmentation/brain_images/'
brain_mask = '/hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation/lgg-mri-segmentation/brain_masks/'
brain_root = '/hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation/'

# %%
converter = O.DataToNpyFiles(brain_out, brain_mask, brain_root, images_name, masks_name, '.tif')

# %%
print(converter)
# Out:
# DataToNpyFiles(image_dir=/hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation/lgg-mri-segmentation/brain_images, mask_dir=/hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation/lgg-mri-segmentation/brain_masks, output_dir=/hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation, image_extension=.tif)

# %%
len(converter.image_paths)
# Out:
# 3929

# %%
len(converter.mask_paths)
# Out:
# 3929

# %%
converter.display_image_and_mask(3)

# %%
images, masks = converter.load_data()

# %%
imshow(images[6])

# %%
imshow(masks[7])

# %%
imshow(Image.open('/hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation/lgg-mri-segmentation/brain_masks/TCGA_CS_4941_19960909_13_mask.tif'))

# %%
converter.print_images_in_dir(brain_mask, 'tif')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3909844/1847071790.py in <module>
# ----> 1 converter.print_images_in_dir(brain_mask, 'tif')
#
# ~/Projects/CS410-Omama/_DATA/gp2/../../omama/utils/data_to_npy_files.py in print_images_in_dir(self, root_dir, image_extension)
#     130                     image = Image.open(os.path.join(root, file))
#     131                     plt.imshow(image)
# --> 132                     plt.show()
#     133
#     134     def reshape_all_images_and_masks(self, new_shape=(None, 512, 512, 1)):
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     366     """
#     367     _warn_if_gui_out_of_main_thread()
# --> 368     return _backend_mod.show(*args, **kwargs)
#     369
#     370
#
# ...

# %%
images[0].shape
# Out:
# (256, 256, 3)

# %%
masks[0].shape
# Out:
# (256, 256)

# %%
converter.reshape_all_images_and_masks()

# %%
for img in images:
    print(img.shape)
# Out:
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# ...

# %%
for img in masks:
    print(img.shape)
# Out:
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# ...

# %%
for i, path in enumerate(converter.image_paths):
    print(converter.mask_paths[i])
    print(path)
# Out:
# /hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation/lgg-mri-segmentation/brain_masks/TCGA_EZ_7264_20010816_3_mask.tif
# /hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation/lgg-mri-segmentation/brain_images/TCGA_FG_7634_20000128_12.tif
# /hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation/lgg-mri-segmentation/brain_masks/TCGA_DU_6399_19830416_20_mask.tif
# /hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation/lgg-mri-segmentation/brain_images/TCGA_CS_6668_20011025_20.tif
# /hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation/lgg-mri-segmentation/brain_masks/TCGA_HT_8111_19980330_4_mask.tif
# /hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation/lgg-mri-segmentation/brain_images/TCGA_HT_A5RC_19990831_2.tif
# /hpcstor6/scratch01/r/ryan.zurrin001/Brain_MRI_Segmentation/lgg-mri-segmentation/brain_masks/TCGA_HT_7680_19970202_8_mask.tif
# ...
