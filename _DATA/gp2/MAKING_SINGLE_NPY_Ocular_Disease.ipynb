# %% [markdown]
# # USE OF SIMPLE API TO CONVERT SEGMENTATION DATASETS TO NPY

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0,'../..')
from PIL import Image
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import omama as O

# %%
images_name = 'images'
masks_name = 'masks'
brain_root = '/hpcstor6/scratch01/r/ryan.zurrin001/Ocular_disease/'
brain_out = '/hpcstor6/scratch01/r/ryan.zurrin001/Ocular_disease/images/'
brain_mask = '/hpcstor6/scratch01/r/ryan.zurrin001/Ocular_disease/masks/'

# %%
converter = O.DataToNpyFiles(brain_out, brain_mask, brain_root, images_name, masks_name, '.jpg')
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████| 6392/6392 [00:08<00:00, 734.66it/s]
# Images and masks saved to /hpcstor6/scratch01/r/ryan.zurrin001/Ocular_disease

# %%
print(converter)
# Out:
# DataToNpyFiles(image_dir=/hpcstor6/scratch01/r/ryan.zurrin001/Ocular_disease/images, mask_dir=/hpcstor6/scratch01/r/ryan.zurrin001/Ocular_disease/masks, output_dir=/hpcstor6/scratch01/r/ryan.zurrin001/Ocular_disease, image_extension=.jpg)

# %%
len(converter.image_paths)
# Out:
# 6392

# %%
len(converter.mask_paths)
# Out:
# 6392

# %%
converter.display_image_and_mask(4)

# %%
images, masks = converter.load_data() # easily  load the imagers and masks now

# %%
converter.reshape_all_images_and_masks()  # shape converter lets you resize fast
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1423/1423 [10:47<00:00,  2.20it/s]

# %%
images[2].shape
# Out:
# (512, 512, 3)

# %%
masks[3].shape
# Out:
# (512, 512)
