# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')
import kaggle_explorer as K
import pydicom

# %%
omama = pydicom.dcmread("/hpcstor6/scratch01/r/ryan.zurrin001/deephealth/dh_dcm_ast/2.25.100023834138724144715875938732458164944/DXm.2.25.114605502330206081390757163180312106015")

# %%
kaggle = pydicom.dcmread("/raid/mpsych/kaggle_mammograms/original/train_images/10006/1874946579.dcm")

# %%
kaggle.pixel_array.max()
# Out:
# 3044

# %%
kaggle.pixel_array.min()
# Out:
# 1500

# %%
omama.pixel_array.max()
# Out:
# 4033

# %%
omama.pixel_array.min()
# Out:
# 286

# %%
omama.pixel_array.shape
# Out:
# (2294, 1914)

# %%
kaggle.pixel_array.shape
# Out:
# (5355, 4915)

# %%
imshow(omama.pixel_array)

# %%
imshow(kaggle.pixel_array)

# %%
omama.PixelData = kaggle.pixel_array[-omama.pixel_array.shape[0]:,-omama.pixel_array.shape[1]:].tobytes()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_487008/2704810092.py in <module>
# ----> 1 omama.PixelData = kaggle.pixel_array[-omama.pixel_array.shape[0]:,-omama.pixel_array.shape[1]:].tobytes()
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/pydicom/dataset.py in pixel_array(self)
#    1613             :class:`numpy.ndarray`.
#    1614         """
# -> 1615         self.convert_pixel_data()
#    1616         return self._pixel_array
#    1617
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/pydicom/dataset.py in convert_pixel_data(self, handler_name)
#    1322             self._convert_pixel_data_using_handler(handler_name)
#    1323         else:
# -> 1324             self._convert_pixel_data_without_handler()
#    1325
#    1326     def _convert_pixel_data_using_handler(self, name):
#
# ...

# %%
imshow(kaggle.pixel_array[2000:omama.pixel_array.shape[0], 2000:omama.pixel_array.shape[1]])
# Out:
# /tmp/ipykernel_487008/3169874971.py:1: UserWarning: Attempting to set identical left == right == -0.5 results in singular transformations; automatically expanding.
#   imshow(kaggle.pixel_array[2000:omama.pixel_array.shape[0], 2000:omama.pixel_array.shape[1]])

# %%
imshow(kaggle.pixel_array[-omama.pixel_array.shape[0]:,-omama.pixel_array.shape[1]:])

# %%
a = kaggle.pixel_array[-omama.pixel_array.shape[0]:,-omama.pixel_array.shape[1]:]

# %%
a.max()
# Out:
# 3044

# %%
a.dtype
# Out:
# dtype('uint16')

# %%
imshow(omama.pixel_array)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_487008/1568590650.py in <module>
# ----> 1 imshow(omama.pixel_array)
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/pydicom/dataset.py in pixel_array(self)
#    1613             :class:`numpy.ndarray`.
#    1614         """
# -> 1615         self.convert_pixel_data()
#    1616         return self._pixel_array
#    1617
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/pydicom/dataset.py in convert_pixel_data(self, handler_name)
#    1322             self._convert_pixel_data_using_handler(handler_name)
#    1323         else:
# -> 1324             self._convert_pixel_data_without_handler()
#    1325
#    1326     def _convert_pixel_data_using_handler(self, name):
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/pydicom/dataset.py in _convert_pixel_data_without_handler(self)
# ...

# %%
omama.pixel_array
# Out:
# array([[26064, 18499, 22049, ...,  2004,  1983,  1937],
#        [ 1973,  1981,  1990, ...,  2003,  1983,  1983],
#        [ 1988,  1986,  2042, ...,  1980,  1986,  1973],
#        ...,
#        [ 3044,  3044,  3044, ...,  3044,  3044,  3044],
#        [ 3044,  3044,  3044, ...,  3044,  3044,  3044],
#        [ 3044,  3044,  3044, ...,  3044,  3044,  3044]], dtype=uint16)

# %%
omama.pixel_array.max()
# Out:
# 41904

# %%
omama
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 192
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital Mammography X-Ray Image Storage - For Presentation
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.114605502330206081390757163180312106015
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.4
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_364'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', '']
# ...

# %%
plt.imshow(omama.pixel_array)

# %%
kaggle
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital X-Ray Image Storage - For Presentation
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.10009.1.2.3.10006.1.1874946579
# (0002, 0010) Transfer Syntax UID                 UI: JPEG 2000 Image Compression (Lossless Only)
# (0002, 0012) Implementation Class UID            UI: 1.2.840.113654.2.3.1995.2.12.0
# (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
# -------------------------------------------------
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.10009.1.2.3.10006.1.1874946579
# (0008, 0023) Content Date                        DA: '20221118'
# (0008, 0033) Content Time                        TM: '183902.142082'
# (0010, 0020) Patient ID                          LO: '10006'
# (0020, 000d) Study Instance UID                  UI: 1.2.840.10009.1.2.3.10006
# ...

# %%
plt.imshow(kaggle.pixel_array)

# %%
omama.pixel_array.dtype
# Out:
# dtype('uint16')

# %%
kaggle.pixel_array.dtype
# Out:
# dtype('uint16')

# %%
kagoma = K.DicomCopyMachine(omama,kaggle,"DXm.1459541791X2.dcm")
# Out:
# New dicom saved to DXm.1459541791X2.dcm

# %%
test = pydicom.dcmread("DXm.1459541791X2.dcm")

# %%
# kagoma.view_dicom()

# %%
test
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 192
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital Mammography X-Ray Image Storage - For Presentation
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.114605502330206081390757163180312106015
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.4
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_364'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', '']
# ...

# %%
plt.imshow(test.pixel_array)

# plt.imshow(test.pixel_array)
# Out:
# Not a JPEG file: starts with 0x00 0x00

# %%
# test.pixel_array.dtype

# %%
/home/ryan.zurrin001/Projects/omama/omama/deep_sight/deepsight2.sh -i /raid/mpsych/kaggle_mammograms/original -o /raid/mpsych/deepsight_out/kaggle_processed/6cfc7d8e99684428b1b381239c44235a/20230218_110322 -cl /raid/mpsych/deepsight_out/kaggle_processed/6cfc7d8e99684428b1b381239c44235a/caselist.txt --additional_params --checks_to_ignore PAC-10 FAC-140 FAC-200 SAC-30 GE-160 SAC-40 SAC-60 SAC-50 SAC-130 HOL-10 HOL-160 FAC-160 FAC-24 FAC-170 FAC-30 FAC-23 PAC-30 FAC-21 FAC-27 FAC-80 FAC-90 FAC-20 IAC-20 HOL-30 HOL-50 HOL-60 HOL-110 HOL-140 HOL-190 HOL-200 HOL-80 HOL-30 HOL-50 HOL-60 HOL-110 HOL-140 HOL-190 HOL-200 HOL-80
