# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import time
import sys
sys.path.insert(0,'../..')
from gp2 import Runner

# %%
R = Runner(verbose=True)
# Out:
# *** GP2 ***
# Working directory: /tmp/tmpdmmbe4zxGP2
# Verbose mode active!

# %%
# load our larger toy dataset (10k images and masks)
images = np.load('/hpcstor6/scratch01/r/ryan.zurrin001/gp2_ocular_images.npy')
masks = np.load('/hpcstor6/scratch01/r/ryan.zurrin001/gp2_ocular_masks.npy')

# %%
plt.imshow(images[10])

# %%
plt.imshow(masks[10])

# %%
len(images)
# Out:
# 6392

# %%
# Check shapes of arrays
print(images.shape)
print(masks.shape)
print(weights.shape)
# Out:
# (6392, 512, 512, 1)
# (6392, 512, 512, 1)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2539932/1139017970.py in <module>
#       2 print(images.shape)
#       3 print(masks.shape)
# ----> 4 print(weights.shape)
#
# AttributeError: 'dict' object has no attribute 'shape'

# %%
weights = {
    'A': 0.5,
    'A_train': 0.1,
    'A_val': 0.3,
    'A_test': 0.6,
    'B': 0.3,
    'B_train': 0.7,
    'B_val': 0.1,
    'B_test': 0.2,
    'Z': 0.2
}

# %%
#
#
weights = np.expand_dims(weights, axis=(1, 2, 3)) # adjust axis values as needed

A = np.concatenate((images, masks, weights), axis=-1)

R.setup_data(images, masks, dataset_size=6392, weights=weights)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# /tmp/ipykernel_2539932/2804735018.py in <module>
#       1 #
#       2 #
# ----> 3 weights = np.expand_dims(weights, axis=(1, 2, 3)) # adjust axis values as needed
#       4
#       5 A = np.concatenate((images, masks, weights), axis=-1)
#
# <__array_function__ internals> in expand_dims(*args, **kwargs)
#
# ~/anaconda3/envs/O/lib/python3.9/site-packages/numpy/lib/shape_base.py in expand_dims(a, axis)
#     595
#     596     out_ndim = len(axis) + a.ndim
# --> 597     axis = normalize_axis_tuple(axis, out_ndim)
#     598
#     599     shape_it = iter(a.shape)
#
# ~/anaconda3/envs/O/lib/python3.9/site-packages/numpy/core/numeric.py in normalize_axis_tuple(axis, ndim, argname, allow_duplicate)
#    1356             pass
#    1357     # Going via an iterator directly is slower than via list comprehension.
# -> 1358     axis = tuple([normalize_axis_index(ax, ndim, argname) for ax in axis])
#    1359     if not allow_duplicate and len(set(axis)) != len(axis):
#    1360         if argname:
#
# ~/anaconda3/envs/O/lib/python3.9/site-packages/numpy/core/numeric.py in <listcomp>(.0)
#    1356             pass
#    1357     # Going via an iterator directly is slower than via list comprehension.
# -> 1358     axis = tuple([normalize_axis_index(ax, ndim, argname) for ax in axis])
#    1359     if not allow_duplicate and len(set(axis)) != len(axis):
#    1360         if argname:
#
# AxisError: axis 3 is out of bounds for array of dimension 3

# %%
RUNS = 5

# %%
for run in range(RUNS):
    print('***')
    print('RUN:', run)
    t0 = time.time()
    R.run_classifier()
    R.run_discriminator()
    R.find_machine_labels()
    R.relabel()
    print('TOOK', time.time()-t0, 'seconds')
# Out:
# ***
# RUN: 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2539932/1143213823.py in <module>
#       3     print('RUN:', run)
#       4     t0 = time.time()
# ----> 5     R.run_classifier()
#       6     R.run_discriminator()
#       7     R.find_machine_labels()
#
# ~/projects/CS410-Omama-1/_EXPERIMENTS/GP2/../../gp2/runner.py in run_classifier(self, patience_counter)
#     121             self.classifier = u
#     122
# --> 123         X_train_, X_train_ids = A_train.to_array()
#     124         X_train_ = X_train_[:, :, :, 0].astype(np.float32)
#     125
#
# AttributeError: 'NoneType' object has no attribute 'to_array'

# %%
R.classifier_scores
# Out:
# [[-201.56130981445312, 1.2717903852462769],
#  [-225.53067016601562, 1.3000315427780151],
#  [-246.53582763671875, 1.3258417844772339],
#  [-265.2281494140625, 1.3436616659164429],
#  [-334.8204650878906, 1.3893414735794067]]

# %%
R.discriminator_scores
# Out:
# [[394.1426086425781, 0.75],
#  [0.4090917110443115, 0.8125],
#  [221.94296264648438, 0.75],
#  [244.54798889160156, 0.8125],
#  [0.2878209948539734, 0.8125]]

# %%
R.plot()
