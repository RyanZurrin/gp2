# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
from glob import glob
from tensorflow import keras
from tensorflow.keras.layers import Input, Conv2D, Dropout, Activation, UpSampling2D, GlobalMaxPooling2D, multiply
from tensorflow.keras.backend import max
from keras_unet_collection import models, base, utils
import os
# Out:
# 2023-04-22 12:16:20.531074: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
import time
import sys
sys.path.insert(0,'../..')
from gp2 import Runner
# Out:
# 2023-04-22 12:16:22.091473: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-04-22 12:16:22.463892: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:07:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-04-22 12:16:22.467989: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:0f:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-04-22 12:16:22.468010: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-04-22 12:16:22.471509: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-04-22 12:16:22.471543: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-04-22 12:16:22.472475: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-04-22 12:16:22.472856: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-04-22 12:16:22.473473: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-04-22 12:16:22.474302: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-04-22 12:16:22.474623: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-04-22 12:16:22.490866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1

# %%
R = Runner(verbose=True, classifier='kresunet2d')
# Out:
# Received dilation rates: [1, 3, 15, 31]
# Received dilation rates are not defined on a per downsampling level basis.
# Automated determinations are applied with the following details:
# 	depth-0, dilation_rate = [1, 3, 15, 31]
# 	depth-1, dilation_rate = [1, 3, 15, 31]
# 	depth-2, dilation_rate = [1, 3, 15]
# 	depth-3, dilation_rate = [1]
# 2023-04-22 12:16:22.549138: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-22 12:16:22.878993: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:07:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-04-22 12:16:22.882537: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:0f:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-04-22 12:16:22.899129: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1
# 2023-04-22 12:16:22.899184: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-04-22 12:16:23.671088: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-04-22 12:16:23.671139: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1
# 2023-04-22 12:16:23.671145: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N Y
# 2023-04-22 12:16:23.671149: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   Y N
# 2023-04-22 12:16:23.683472: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 38425 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:07:00.0, compute capability: 8.0)
# 2023-04-22 12:16:23.686102: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 38425 MB memory) -> physical GPU (device: 1, name: A100-SXM4-40GB, pci bus id: 0000:0f:00.0, compute capability: 8.0)
# *** GP2  KResUNet2D ***
# Working directory: /tmp/tmp6tiskkldGP2
# Verbose mode active!
# Model: "resunet_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# resunet_input_mapping (Conv2D)  (None, 512, 512, 16) 32          input_1[0][0]
# __________________________________________________________________________________________________
# resunet_input_activation (PReLU (None, 512, 512, 16) 4194304     resunet_input_mapping[0][0]
# __________________________________________________________________________________________________
# resunet_res0_stack0_0 (Conv2D)  (None, 512, 512, 16) 2320        resunet_input_activation[0][0]
# __________________________________________________________________________________________________
# resunet_res0_stack1_0 (Conv2D)  (None, 512, 512, 16) 2320        resunet_input_activation[0][0]
# __________________________________________________________________________________________________
# resunet_res0_stack2_0 (Conv2D)  (None, 512, 512, 16) 2320        resunet_input_activation[0][0]
# __________________________________________________________________________________________________
# resunet_res0_stack3_0 (Conv2D)  (None, 512, 512, 16) 2320        resunet_input_activation[0][0]
# __________________________________________________________________________________________________
# resunet_res0_stack0_0_activatio (None, 512, 512, 16) 4194304     resunet_res0_stack0_0[0][0]
# __________________________________________________________________________________________________
# resunet_res0_stack1_0_activatio (None, 512, 512, 16) 4194304     resunet_res0_stack1_0[0][0]
# __________________________________________________________________________________________________
# resunet_res0_stack2_0_activatio (None, 512, 512, 16) 4194304     resunet_res0_stack2_0[0][0]
# __________________________________________________________________________________________________
# resunet_res0_stack3_0_activatio (None, 512, 512, 16) 4194304     resunet_res0_stack3_0[0][0]
# __________________________________________________________________________________________________
# resunet_res0_stack0_1 (Conv2D)  (None, 512, 512, 16) 2320        resunet_res0_stack0_0_activation[
# __________________________________________________________________________________________________
# resunet_res0_stack1_1 (Conv2D)  (None, 512, 512, 16) 2320        resunet_res0_stack1_0_activation[
# __________________________________________________________________________________________________
# resunet_res0_stack2_1 (Conv2D)  (None, 512, 512, 16) 2320        resunet_res0_stack2_0_activation[
# __________________________________________________________________________________________________
# resunet_res0_stack3_1 (Conv2D)  (None, 512, 512, 16) 2320        resunet_res0_stack3_0_activation[
# __________________________________________________________________________________________________
# resunet_res0_stack0_1_activatio (None, 512, 512, 16) 4194304     resunet_res0_stack0_1[0][0]
# __________________________________________________________________________________________________
# resunet_res0_stack1_1_activatio (None, 512, 512, 16) 4194304     resunet_res0_stack1_1[0][0]
# __________________________________________________________________________________________________
# resunet_res0_stack2_1_activatio (None, 512, 512, 16) 4194304     resunet_res0_stack2_1[0][0]
# __________________________________________________________________________________________________
# resunet_res0_stack3_1_activatio (None, 512, 512, 16) 4194304     resunet_res0_stack3_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 512, 512, 16) 0           resunet_res0_stack0_1_activation[
#                                                                  resunet_res0_stack1_1_activation[
#                                                                  resunet_res0_stack2_1_activation[
#                                                                  resunet_res0_stack3_1_activation[
# __________________________________________________________________________________________________
# resunet_down0_stride_conv (Conv (None, 256, 256, 32) 2080        add[0][0]
# __________________________________________________________________________________________________
# resunet_down0_activation (PReLU (None, 256, 256, 32) 2097152     resunet_down0_stride_conv[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_1_stack0_0 (Co (None, 256, 256, 32) 9248        resunet_down0_activation[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_1_stack1_0 (Co (None, 256, 256, 32) 9248        resunet_down0_activation[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_1_stack2_0 (Co (None, 256, 256, 32) 9248        resunet_down0_activation[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_1_stack3_0 (Co (None, 256, 256, 32) 9248        resunet_down0_activation[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_1_stack0_0_act (None, 256, 256, 32) 2097152     resunet_resblock_1_stack0_0[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_1_stack1_0_act (None, 256, 256, 32) 2097152     resunet_resblock_1_stack1_0[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_1_stack2_0_act (None, 256, 256, 32) 2097152     resunet_resblock_1_stack2_0[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_1_stack3_0_act (None, 256, 256, 32) 2097152     resunet_resblock_1_stack3_0[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_1_stack0_1 (Co (None, 256, 256, 32) 9248        resunet_resblock_1_stack0_0_activ
# __________________________________________________________________________________________________
# resunet_resblock_1_stack1_1 (Co (None, 256, 256, 32) 9248        resunet_resblock_1_stack1_0_activ
# __________________________________________________________________________________________________
# resunet_resblock_1_stack2_1 (Co (None, 256, 256, 32) 9248        resunet_resblock_1_stack2_0_activ
# __________________________________________________________________________________________________
# resunet_resblock_1_stack3_1 (Co (None, 256, 256, 32) 9248        resunet_resblock_1_stack3_0_activ
# __________________________________________________________________________________________________
# resunet_resblock_1_stack0_1_act (None, 256, 256, 32) 2097152     resunet_resblock_1_stack0_1[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_1_stack1_1_act (None, 256, 256, 32) 2097152     resunet_resblock_1_stack1_1[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_1_stack2_1_act (None, 256, 256, 32) 2097152     resunet_resblock_1_stack2_1[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_1_stack3_1_act (None, 256, 256, 32) 2097152     resunet_resblock_1_stack3_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256, 256, 32) 0           resunet_resblock_1_stack0_1_activ
#                                                                  resunet_resblock_1_stack1_1_activ
#                                                                  resunet_resblock_1_stack2_1_activ
#                                                                  resunet_resblock_1_stack3_1_activ
# __________________________________________________________________________________________________
# resunet_down1_stride_conv (Conv (None, 128, 128, 64) 8256        add_1[0][0]
# __________________________________________________________________________________________________
# resunet_down1_activation (PReLU (None, 128, 128, 64) 1048576     resunet_down1_stride_conv[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_2_stack0_0 (Co (None, 128, 128, 64) 36928       resunet_down1_activation[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_2_stack1_0 (Co (None, 128, 128, 64) 36928       resunet_down1_activation[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_2_stack2_0 (Co (None, 128, 128, 64) 36928       resunet_down1_activation[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_2_stack0_0_act (None, 128, 128, 64) 1048576     resunet_resblock_2_stack0_0[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_2_stack1_0_act (None, 128, 128, 64) 1048576     resunet_resblock_2_stack1_0[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_2_stack2_0_act (None, 128, 128, 64) 1048576     resunet_resblock_2_stack2_0[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_2_stack0_1 (Co (None, 128, 128, 64) 36928       resunet_resblock_2_stack0_0_activ
# __________________________________________________________________________________________________
# resunet_resblock_2_stack1_1 (Co (None, 128, 128, 64) 36928       resunet_resblock_2_stack1_0_activ
# __________________________________________________________________________________________________
# resunet_resblock_2_stack2_1 (Co (None, 128, 128, 64) 36928       resunet_resblock_2_stack2_0_activ
# __________________________________________________________________________________________________
# resunet_resblock_2_stack0_1_act (None, 128, 128, 64) 1048576     resunet_resblock_2_stack0_1[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_2_stack1_1_act (None, 128, 128, 64) 1048576     resunet_resblock_2_stack1_1[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_2_stack2_1_act (None, 128, 128, 64) 1048576     resunet_resblock_2_stack2_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 128, 128, 64) 0           resunet_resblock_2_stack0_1_activ
#                                                                  resunet_resblock_2_stack1_1_activ
#                                                                  resunet_resblock_2_stack2_1_activ
# __________________________________________________________________________________________________
# resunet_down2_stride_conv (Conv (None, 64, 64, 128)  32896       add_2[0][0]
# __________________________________________________________________________________________________
# resunet_down2_activation (PReLU (None, 64, 64, 128)  524288      resunet_down2_stride_conv[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_3_stack0_0 (Co (None, 64, 64, 128)  147584      resunet_down2_activation[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_3_stack0_0_act (None, 64, 64, 128)  524288      resunet_resblock_3_stack0_0[0][0]
# __________________________________________________________________________________________________
# resunet_resblock_3_stack0_1 (Co (None, 64, 64, 128)  147584      resunet_resblock_3_stack0_0_activ
# __________________________________________________________________________________________________
# resunet_resblock_3_stack0_1_act (None, 64, 64, 128)  524288      resunet_resblock_3_stack0_1[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_bottom_avepool_b4  (None, 128)          0           resunet_resblock_3_stack0_1_activ
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r6_ (None, 64, 64, 128)  1152        resunet_resblock_3_stack0_1_activ
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r9_ (None, 64, 64, 128)  1152        resunet_resblock_3_stack0_1_activ
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r12 (None, 64, 64, 128)  1152        resunet_resblock_3_stack0_1_activ
# __________________________________________________________________________________________________
# tf.expand_dims (TFOpLambda)     (None, 1, 128)       0           resunet_aspp_bottom_avepool_b4[0]
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r6_ (None, 64, 64, 128)  512         resunet_aspp_bottom_sepconv_r6_0_
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r9_ (None, 64, 64, 128)  512         resunet_aspp_bottom_sepconv_r9_0_
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r12 (None, 64, 64, 128)  512         resunet_aspp_bottom_sepconv_r12_0
# __________________________________________________________________________________________________
# tf.expand_dims_1 (TFOpLambda)   (None, 1, 1, 128)    0           tf.expand_dims[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r6_ (None, 64, 64, 128)  0           resunet_aspp_bottom_sepconv_r6_0_
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r9_ (None, 64, 64, 128)  0           resunet_aspp_bottom_sepconv_r9_0_
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r12 (None, 64, 64, 128)  0           resunet_aspp_bottom_sepconv_r12_0
# __________________________________________________________________________________________________
# resunet_aspp_bottom_conv_b4 (Co (None, 1, 1, 16)     2064        tf.expand_dims_1[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r6_ (None, 64, 64, 16)   2048        resunet_aspp_bottom_sepconv_r6_0_
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r9_ (None, 64, 64, 16)   2048        resunet_aspp_bottom_sepconv_r9_0_
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r12 (None, 64, 64, 16)   2048        resunet_aspp_bottom_sepconv_r12_0
# __________________________________________________________________________________________________
# resunet_aspp_bottom_conv_b4_act (None, 1, 1, 16)     16          resunet_aspp_bottom_conv_b4[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_bottom_conv_b0 (Co (None, 64, 64, 16)   2064        resunet_resblock_3_stack0_1_activ
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r6_ (None, 64, 64, 16)   64          resunet_aspp_bottom_sepconv_r6_0_
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r9_ (None, 64, 64, 16)   64          resunet_aspp_bottom_sepconv_r9_0_
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r12 (None, 64, 64, 16)   64          resunet_aspp_bottom_sepconv_r12_0
# __________________________________________________________________________________________________
# resunet_aspp_bottom_resize_b4 ( (None, 64, 64, 16)   0           resunet_aspp_bottom_conv_b4_activ
# __________________________________________________________________________________________________
# resunet_aspp_bottom_conv_b0_act (None, 64, 64, 16)   65536       resunet_aspp_bottom_conv_b0[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r6_ (None, 64, 64, 16)   0           resunet_aspp_bottom_sepconv_r6_0_
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r9_ (None, 64, 64, 16)   0           resunet_aspp_bottom_sepconv_r9_0_
# __________________________________________________________________________________________________
# resunet_aspp_bottom_sepconv_r12 (None, 64, 64, 16)   0           resunet_aspp_bottom_sepconv_r12_0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 80)   0           resunet_aspp_bottom_resize_b4[0][
#                                                                  resunet_aspp_bottom_conv_b0_activ
#                                                                  resunet_aspp_bottom_sepconv_r6_0_
#                                                                  resunet_aspp_bottom_sepconv_r9_0_
#                                                                  resunet_aspp_bottom_sepconv_r12_0
# __________________________________________________________________________________________________
# resunet_up0_decode_trans_conv ( (None, 128, 128, 64) 46144       concatenate[0][0]
# __________________________________________________________________________________________________
# resunet_up0_decode_activation ( (None, 128, 128, 64) 1048576     resunet_up0_decode_trans_conv[0][
# __________________________________________________________________________________________________
# resunet_up0_concat (Concatenate (None, 128, 128, 128 0           resunet_up0_decode_activation[0][
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# resunet_up0_resblock_stack0_0 ( (None, 128, 128, 64) 73792       resunet_up0_concat[0][0]
# __________________________________________________________________________________________________
# resunet_up0_resblock_stack1_0 ( (None, 128, 128, 64) 73792       resunet_up0_concat[0][0]
# __________________________________________________________________________________________________
# resunet_up0_resblock_stack2_0 ( (None, 128, 128, 64) 73792       resunet_up0_concat[0][0]
# __________________________________________________________________________________________________
# resunet_up0_resblock_stack0_0_a (None, 128, 128, 64) 1048576     resunet_up0_resblock_stack0_0[0][
# __________________________________________________________________________________________________
# resunet_up0_resblock_stack1_0_a (None, 128, 128, 64) 1048576     resunet_up0_resblock_stack1_0[0][
# __________________________________________________________________________________________________
# resunet_up0_resblock_stack2_0_a (None, 128, 128, 64) 1048576     resunet_up0_resblock_stack2_0[0][
# __________________________________________________________________________________________________
# resunet_up0_resblock_stack0_1 ( (None, 128, 128, 64) 36928       resunet_up0_resblock_stack0_0_act
# __________________________________________________________________________________________________
# resunet_up0_resblock_stack1_1 ( (None, 128, 128, 64) 36928       resunet_up0_resblock_stack1_0_act
# __________________________________________________________________________________________________
# resunet_up0_resblock_stack2_1 ( (None, 128, 128, 64) 36928       resunet_up0_resblock_stack2_0_act
# __________________________________________________________________________________________________
# resunet_up0_resblock_stack0_1_a (None, 128, 128, 64) 1048576     resunet_up0_resblock_stack0_1[0][
# __________________________________________________________________________________________________
# resunet_up0_resblock_stack1_1_a (None, 128, 128, 64) 1048576     resunet_up0_resblock_stack1_1[0][
# __________________________________________________________________________________________________
# resunet_up0_resblock_stack2_1_a (None, 128, 128, 64) 1048576     resunet_up0_resblock_stack2_1[0][
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 128, 64) 0           resunet_up0_resblock_stack0_1_act
#                                                                  resunet_up0_resblock_stack1_1_act
#                                                                  resunet_up0_resblock_stack2_1_act
# __________________________________________________________________________________________________
# resunet_up1_decode_trans_conv ( (None, 256, 256, 32) 18464       add_3[0][0]
# __________________________________________________________________________________________________
# resunet_up1_decode_activation ( (None, 256, 256, 32) 2097152     resunet_up1_decode_trans_conv[0][
# __________________________________________________________________________________________________
# resunet_up1_concat (Concatenate (None, 256, 256, 64) 0           resunet_up1_decode_activation[0][
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack0_0 ( (None, 256, 256, 32) 18464       resunet_up1_concat[0][0]
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack1_0 ( (None, 256, 256, 32) 18464       resunet_up1_concat[0][0]
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack2_0 ( (None, 256, 256, 32) 18464       resunet_up1_concat[0][0]
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack3_0 ( (None, 256, 256, 32) 18464       resunet_up1_concat[0][0]
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack0_0_a (None, 256, 256, 32) 2097152     resunet_up1_resblock_stack0_0[0][
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack1_0_a (None, 256, 256, 32) 2097152     resunet_up1_resblock_stack1_0[0][
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack2_0_a (None, 256, 256, 32) 2097152     resunet_up1_resblock_stack2_0[0][
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack3_0_a (None, 256, 256, 32) 2097152     resunet_up1_resblock_stack3_0[0][
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack0_1 ( (None, 256, 256, 32) 9248        resunet_up1_resblock_stack0_0_act
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack1_1 ( (None, 256, 256, 32) 9248        resunet_up1_resblock_stack1_0_act
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack2_1 ( (None, 256, 256, 32) 9248        resunet_up1_resblock_stack2_0_act
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack3_1 ( (None, 256, 256, 32) 9248        resunet_up1_resblock_stack3_0_act
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack0_1_a (None, 256, 256, 32) 2097152     resunet_up1_resblock_stack0_1[0][
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack1_1_a (None, 256, 256, 32) 2097152     resunet_up1_resblock_stack1_1[0][
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack2_1_a (None, 256, 256, 32) 2097152     resunet_up1_resblock_stack2_1[0][
# __________________________________________________________________________________________________
# resunet_up1_resblock_stack3_1_a (None, 256, 256, 32) 2097152     resunet_up1_resblock_stack3_1[0][
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 256, 256, 32) 0           resunet_up1_resblock_stack0_1_act
#                                                                  resunet_up1_resblock_stack1_1_act
#                                                                  resunet_up1_resblock_stack2_1_act
#                                                                  resunet_up1_resblock_stack3_1_act
# __________________________________________________________________________________________________
# resunet_up2_decode_trans_conv ( (None, 512, 512, 16) 4624        add_4[0][0]
# __________________________________________________________________________________________________
# resunet_up2_decode_activation ( (None, 512, 512, 16) 4194304     resunet_up2_decode_trans_conv[0][
# __________________________________________________________________________________________________
# resunet_up2_concat (Concatenate (None, 512, 512, 32) 0           resunet_up2_decode_activation[0][
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack0_0 ( (None, 512, 512, 16) 4624        resunet_up2_concat[0][0]
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack1_0 ( (None, 512, 512, 16) 4624        resunet_up2_concat[0][0]
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack2_0 ( (None, 512, 512, 16) 4624        resunet_up2_concat[0][0]
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack3_0 ( (None, 512, 512, 16) 4624        resunet_up2_concat[0][0]
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack0_0_a (None, 512, 512, 16) 4194304     resunet_up2_resblock_stack0_0[0][
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack1_0_a (None, 512, 512, 16) 4194304     resunet_up2_resblock_stack1_0[0][
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack2_0_a (None, 512, 512, 16) 4194304     resunet_up2_resblock_stack2_0[0][
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack3_0_a (None, 512, 512, 16) 4194304     resunet_up2_resblock_stack3_0[0][
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack0_1 ( (None, 512, 512, 16) 2320        resunet_up2_resblock_stack0_0_act
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack1_1 ( (None, 512, 512, 16) 2320        resunet_up2_resblock_stack1_0_act
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack2_1 ( (None, 512, 512, 16) 2320        resunet_up2_resblock_stack2_0_act
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack3_1 ( (None, 512, 512, 16) 2320        resunet_up2_resblock_stack3_0_act
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack0_1_a (None, 512, 512, 16) 4194304     resunet_up2_resblock_stack0_1[0][
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack1_1_a (None, 512, 512, 16) 4194304     resunet_up2_resblock_stack1_1[0][
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack2_1_a (None, 512, 512, 16) 4194304     resunet_up2_resblock_stack2_1[0][
# __________________________________________________________________________________________________
# resunet_up2_resblock_stack3_1_a (None, 512, 512, 16) 4194304     resunet_up2_resblock_stack3_1[0][
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 512, 512, 16) 0           resunet_up2_resblock_stack0_1_act
#                                                                  resunet_up2_resblock_stack1_1_act
#                                                                  resunet_up2_resblock_stack2_1_act
#                                                                  resunet_up2_resblock_stack3_1_act
# __________________________________________________________________________________________________
# resunet_concat_out (Concatenate (None, 512, 512, 32) 0           resunet_input_activation[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_out_avepool_b4 (Gl (None, 32)           0           resunet_concat_out[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r6_0_d (None, 512, 512, 32) 288         resunet_concat_out[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r9_0_d (None, 512, 512, 32) 288         resunet_concat_out[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r12_0_ (None, 512, 512, 32) 288         resunet_concat_out[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_2 (TFOpLambda)   (None, 1, 32)        0           resunet_aspp_out_avepool_b4[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r6_0_d (None, 512, 512, 32) 128         resunet_aspp_out_sepconv_r6_0_dep
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r9_0_d (None, 512, 512, 32) 128         resunet_aspp_out_sepconv_r9_0_dep
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r12_0_ (None, 512, 512, 32) 128         resunet_aspp_out_sepconv_r12_0_de
# __________________________________________________________________________________________________
# tf.expand_dims_3 (TFOpLambda)   (None, 1, 1, 32)     0           tf.expand_dims_2[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r6_0_d (None, 512, 512, 32) 0           resunet_aspp_out_sepconv_r6_0_dep
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r9_0_d (None, 512, 512, 32) 0           resunet_aspp_out_sepconv_r9_0_dep
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r12_0_ (None, 512, 512, 32) 0           resunet_aspp_out_sepconv_r12_0_de
# __________________________________________________________________________________________________
# resunet_aspp_out_conv_b4 (Conv2 (None, 1, 1, 8)      264         tf.expand_dims_3[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r6_0_p (None, 512, 512, 8)  256         resunet_aspp_out_sepconv_r6_0_dep
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r9_0_p (None, 512, 512, 8)  256         resunet_aspp_out_sepconv_r9_0_dep
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r12_0_ (None, 512, 512, 8)  256         resunet_aspp_out_sepconv_r12_0_de
# __________________________________________________________________________________________________
# resunet_aspp_out_conv_b4_activa (None, 1, 1, 8)      8           resunet_aspp_out_conv_b4[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_out_conv_b0 (Conv2 (None, 512, 512, 8)  264         resunet_concat_out[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r6_0_p (None, 512, 512, 8)  32          resunet_aspp_out_sepconv_r6_0_poi
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r9_0_p (None, 512, 512, 8)  32          resunet_aspp_out_sepconv_r9_0_poi
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r12_0_ (None, 512, 512, 8)  32          resunet_aspp_out_sepconv_r12_0_po
# __________________________________________________________________________________________________
# resunet_aspp_out_resize_b4 (Lam (None, 512, 512, 8)  0           resunet_aspp_out_conv_b4_activati
# __________________________________________________________________________________________________
# resunet_aspp_out_conv_b0_activa (None, 512, 512, 8)  2097152     resunet_aspp_out_conv_b0[0][0]
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r6_0_p (None, 512, 512, 8)  0           resunet_aspp_out_sepconv_r6_0_poi
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r9_0_p (None, 512, 512, 8)  0           resunet_aspp_out_sepconv_r9_0_poi
# __________________________________________________________________________________________________
# resunet_aspp_out_sepconv_r12_0_ (None, 512, 512, 8)  0           resunet_aspp_out_sepconv_r12_0_po
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512, 512, 40) 0           resunet_aspp_out_resize_b4[0][0]
#                                                                  resunet_aspp_out_conv_b0_activati
#                                                                  resunet_aspp_out_sepconv_r6_0_poi
#                                                                  resunet_aspp_out_sepconv_r9_0_poi
#                                                                  resunet_aspp_out_sepconv_r12_0_po
# __________________________________________________________________________________________________
# resunet_output (Conv2D)         (None, 512, 512, 1)  41          concatenate_1[0][0]
# __________________________________________________________________________________________________
# resunet_output_activation (Acti (None, 512, 512, 1)  0           resunet_output[0][0]
# ==================================================================================================
# Total params: 132,872,545
# Trainable params: 132,871,441
# Non-trainable params: 1,104
# __________________________________________________________________________________________________

# %%
# load our larger toy dataset (10k images and masks)
images = np.load('/hpcstor6/scratch01/r/ryan.zurrin001/GP2TOYEXAMPLE_LARGE/images.npy')
masks = np.load('/hpcstor6/scratch01/r/ryan.zurrin001/GP2TOYEXAMPLE_LARGE/masks.npy')

# %%
images = images[:5000]
masks = masks[:5000]

# %%
images.shape
# Out:
# (5000, 512, 512, 1)

# %%
masks.shape
# Out:
# (5000, 512, 512, 1)

# %%
weights = {
    'A': 0.5,
    'A_train': 0.1,
    'A_val': 0.3,
    'A_test': 0.6,
    'B': 0.3,
    'B_train': 0.7,
    'B_val': 0.1,
    'B_test': 0.2,
    'Z': 0.2
}
PERCENT_TO_REPLACE = 30

# %%
R.setup_data(images, masks, dataset_size=10000, weights=weights)
# Out:
# Weights OK!

# %%
RUNS = 5

# %%
for run in range(RUNS):
    print('***')
    print('RUN:', run)
    t0 = time.time()
    R.run_classifier()
    R.run_discriminator()
    l = R.find_machine_labels()
    if l == 0:
        print('No more machine labels.')
        print('TOOK', time.time()-t0, 'seconds')
        break
    R.relabel(percent_to_replace=PERCENT_TO_REPLACE)
    print('TOOK', time.time()-t0, 'seconds')
# Out:
# ***
# RUN: 0
# 2023-04-22 12:16:30.495333: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-04-22 12:16:30.496813: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245755000 Hz
# Epoch 1/100
# 2023-04-22 12:16:39.151223: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-04-22 12:16:39.884668: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-04-22 12:16:39.895066: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-04-22 12:16:40.676507: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2023-04-22 12:16:41.468629: W tensorflow/stream_executor/gpu/asm_compiler.cc:191] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.0
# 2023-04-22 12:16:41.468655: W tensorflow/stream_executor/gpu/asm_compiler.cc:194] Used ptxas at ptxas
# 2023-04-22 12:16:41.468719: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Unimplemented: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-04-22 12:16:54.827464: W tensorflow/core/common_runtime/bfc_allocator.cc:456] Allocator (GPU_0_bfc) ran out of memory trying to allocate 256.00MiB (rounded to 268435456)requested by op resunet_model/resunet_up1_resblock_stack0_1/Conv2D
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-04-22 12:16:54.827585: I tensorflow/core/common_runtime/bfc_allocator.cc:991] BFCAllocator dump for GPU_0_bfc
# 2023-04-22 12:16:54.827602: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (256): 	Total Chunks: 363, Chunks in use: 352. 90.8KiB allocated for chunks. 88.0KiB in use in bin. 28.8KiB client-requested in use in bin.
# 2023-04-22 12:16:54.827614: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (512): 	Total Chunks: 53, Chunks in use: 47. 27.8KiB allocated for chunks. 24.5KiB in use in bin. 23.7KiB client-requested in use in bin.
# 2023-04-22 12:16:54.827625: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1024): 	Total Chunks: 25, Chunks in use: 23. 27.0KiB allocated for chunks. 25.0KiB in use in bin. 23.9KiB client-requested in use in bin.
# 2023-04-22 12:16:54.827636: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2048): 	Total Chunks: 8, Chunks in use: 8. 16.8KiB allocated for chunks. 16.8KiB in use in bin. 15.0KiB client-requested in use in bin.
# 2023-04-22 12:16:54.827647: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4096): 	Total Chunks: 26, Chunks in use: 26. 114.0KiB allocated for chunks. 114.0KiB in use in bin. 114.0KiB client-requested in use in bin.
# 2023-04-22 12:16:54.827658: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8192): 	Total Chunks: 60, Chunks in use: 60. 524.5KiB allocated for chunks. 524.5KiB in use in bin. 517.5KiB client-requested in use in bin.
# 2023-04-22 12:16:54.827669: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16384): 	Total Chunks: 29, Chunks in use: 29. 518.0KiB allocated for chunks. 518.0KiB in use in bin. 518.0KiB client-requested in use in bin.
# 2023-04-22 12:16:54.827679: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (32768): 	Total Chunks: 44, Chunks in use: 44. 1.54MiB allocated for chunks. 1.54MiB in use in bin. 1.54MiB client-requested in use in bin.
# 2023-04-22 12:16:54.827689: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (65536): 	Total Chunks: 26, Chunks in use: 26. 1.84MiB allocated for chunks. 1.84MiB in use in bin. 1.84MiB client-requested in use in bin.
# 2023-04-22 12:16:54.827699: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (131072): 	Total Chunks: 37, Chunks in use: 37. 5.25MiB allocated for chunks. 5.25MiB in use in bin. 5.25MiB client-requested in use in bin.
# 2023-04-22 12:16:54.827709: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (262144): 	Total Chunks: 14, Chunks in use: 14. 3.90MiB allocated for chunks. 3.90MiB in use in bin. 3.84MiB client-requested in use in bin.
# 2023-04-22 12:16:54.827719: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (524288): 	Total Chunks: 6, Chunks in use: 6. 3.38MiB allocated for chunks. 3.38MiB in use in bin. 3.38MiB client-requested in use in bin.
# 2023-04-22 12:16:54.827729: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1048576): 	Total Chunks: 3, Chunks in use: 3. 3.00MiB allocated for chunks. 3.00MiB in use in bin. 3.00MiB client-requested in use in bin.
# 2023-04-22 12:16:54.827739: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2097152): 	Total Chunks: 23, Chunks in use: 23. 46.00MiB allocated for chunks. 46.00MiB in use in bin. 46.00MiB client-requested in use in bin.
# 2023-04-22 12:16:54.827750: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4194304): 	Total Chunks: 61, Chunks in use: 61. 244.00MiB allocated for chunks. 244.00MiB in use in bin. 244.00MiB client-requested in use in bin.
# 2023-04-22 12:16:54.827760: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8388608): 	Total Chunks: 84, Chunks in use: 83. 672.00MiB allocated for chunks. 664.00MiB in use in bin. 664.00MiB client-requested in use in bin.
# 2023-04-22 12:16:54.827775: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16777216): 	Total Chunks: 55, Chunks in use: 54. 888.00MiB allocated for chunks. 864.00MiB in use in bin. 864.00MiB client-requested in use in bin.
# 2023-04-22 12:16:54.827785: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (33554432): 	Total Chunks: 4, Chunks in use: 4. 136.00MiB allocated for chunks. 136.00MiB in use in bin. 136.00MiB client-requested in use in bin.
# 2023-04-22 12:16:54.827795: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (67108864): 	Total Chunks: 18, Chunks in use: 18. 1.25GiB allocated for chunks. 1.25GiB in use in bin. 1.22GiB client-requested in use in bin.
# 2023-04-22 12:16:54.827805: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (134217728): 	Total Chunks: 40, Chunks in use: 40. 5.34GiB allocated for chunks. 5.34GiB in use in bin. 5.31GiB client-requested in use in bin.
# 2023-04-22 12:16:54.827816: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (268435456): 	Total Chunks: 75, Chunks in use: 75. 28.98GiB allocated for chunks. 28.98GiB in use in bin. 28.43GiB client-requested in use in bin.
# 2023-04-22 12:16:54.827825: I tensorflow/core/common_runtime/bfc_allocator.cc:1014] Bin for 256.00MiB was 256.00MiB, Chunk State:
# 2023-04-22 12:16:54.827832: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Next region of size 40291729408
# 2023-04-22 12:16:54.827845: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f92f6000000 of size 1280 by op ScratchBuffer action_count 11259128018139527 step 0 next 1
# 2023-04-22 12:16:54.827853: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f92f6000500 of size 256 by op Fill action_count 11259128018139537 step 0 next 2
# 2023-04-22 12:16:54.827861: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f92f6000600 of size 256 by op Sub action_count 11259128018139529 step 0 next 3
# 2023-04-22 12:16:54.827868: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f92f6000700 of size 256 by op Sub action_count 11259128018139530 step 0 next 4
# 2023-04-22 12:16:54.827875: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f92f6000800 of size 256 by op Add action_count 11259128018139534 step 0 next 5
# 2023-04-22 12:16:54.827882: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f92f6000900 of size 256 by op Fill action_count 11259128018139538 step 0 next 6
# 2023-04-22 12:16:54.827889: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f92f6000a00 of size 16777216 by op Fill action_count 11259128018139539 step 0 next 7
# 2023-04-22 12:16:54.827896: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f92f7000a00 of size 256 by op Fill action_count 11259128018139549 step 0 next 11
# 2023-04-22 12:16:54.827903: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f92f
I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 2 Chunks of size 710494208 totalling 1.32GiB
# 2023-04-22 12:17:24.872908: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 737280000 totalling 703.12MiB
# 2023-04-22 12:17:24.872912: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 952573952 totalling 908.45MiB
# 2023-04-22 12:17:24.872915: I tensorflow/core/common_runtime/bfc_allocator.cc:1058] Sum Total of in-use chunks: 37.49GiB
# 2023-04-22 12:17:24.872919: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] total_region_allocated_bytes_: 40291729408 memory_limit_: 40291729408 available bytes: 0 curr_region_allocation_bytes_: 80583458816
# 2023-04-22 12:17:24.872926: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Stats:
# Limit:                     40291729408
# InUse:                     40258166784
# MaxInUse:                  40258185472
# NumAllocs:                        1531
# MaxAllocSize:               1904292096
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-04-22 12:17:24.872949: W tensorflow/core/common_runtime/bfc_allocator.cc:467] ****************************************************************************************************
# 2023-04-22 12:17:24.872977: W tensorflow/core/framework/op_kernel.cc:1767] OP_REQUIRES failed at batchtospace_op.cc:179 : Resource exhausted: OOM when allocating tensor with shape[64,256,256,32] and type half on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_1987430/1551727473.py in <module>
#       3     print('RUN:', run)
#       4     t0 = time.time()
# ----> 5     R.run_classifier()
#       6     R.run_discriminator()
#       7     l = R.find_machine_labels()
#
# ~/Projects/CS410-Omama/_EXPERIMENTS/GP2/../../gp2/runner.py in run_classifier(self, patience_counter)
#     166         y_val_ = y_val_[:, :, :, 1].astype(np.float32)
#     167
# --> 168         history = u.train(X_train_, y_train_, X_val_, y_val_,
#     169                           patience_counter=patience_counter)
#     170
#
# ~/Projects/CS410-Omama/_EXPERIMENTS/GP2/../../gp2/gp2/base_keras_segmentation_classifier.py in train(self, X_train, y_train, X_val, y_val, patience_counter, batch_size, epochs, call_backs)
#      45             call_backs = call_backs
#      46
# ---> 47         history = self.model.fit(X_train, y_train,
#      48                                  batch_size=batch_size,
#      49                                  epochs=epochs,
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     948         # Lifting succeeded, so variables are initialized and we can run the
#     949         # stateless function.
# --> 950         return self._stateless_fn(*args, **kwds)
#     951     else:
#     952       _, _, _, filtered_flat_args = \
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3021       (graph_function,
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958         and executing_eagerly):
#    1959       # No tape is watching; skip to running the function.
# -> 1960       return self._build_call_outputs(self._inference_function.call(
#    1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[64,256,256,32] and type half on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node resunet_model/resunet_up1_resblock_stack0_1/Conv2D (defined at home/ryan.zurrin001/Projects/CS410-Omama/_EXPERIMENTS/GP2/../../gp2/gp2/base_keras_segmentation_classifier.py:47) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_train_function_20976]
#
# Function call stack:
# train_function

# %%
R.classifier_scores

# %%
R.discriminator_scores

# %%
R.plot()
