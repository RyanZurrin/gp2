# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import datasetCircles as circles

# %%
no_of_samples = 100000
imageHeight = 512
imageWidth = 512

# %%
images, noiseImg, labels = circles.build_data(no_of_samples, imageWidth, imageHeight)

# %%
labels.shape, images.shape, noiseImg.shape

# %%
imshow(images[59])

# %%
imshow(noiseImg[59])

# %%
imshow(labels[59])

# %%
labels.max()

# %%
imshow(labels[59].astype(np.bool))

# %%
np.save("/hpcstor6/scratch01/r/ryan.zurrin001/GP2TOYEXAMPLE_EXTRALARGE/labels.npy", labels.astype(np.bool))

# %%
np.save("/hpcstor6/scratch01/r/ryan.zurrin001/GP2TOYEXAMPLE_EXTRALARGE/images.npy", noiseImg.astype(np.uint8))

# %%
print('all saved')

# %%
noiseImg.dtype

# %%
noiseImg.max()

# %%
labels.dtype

# %%
labels.max()

# %%
# images = np.load("NewImages.npy")
# labels = np.load("NewLabels.npy")
# noisedImg = = np.load("NewnoisedImages.npy")
